# %%
# %pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 1.1/1.1 MB 10.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.4/1.4 MB 12.5 MB/s eta 0:00:00
# ...
#      --------------------------------------- 22.7/22.7 MB 10.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.1/6.1 MB 11.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pyproj.exe is installed in 'C:\Users\conno\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fio.exe is installed in 'C:\Users\conno\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import geopandas as gpd
import os
import numpy as np
import pandas as pd
from shapely.geometry import Point
from shapely.geometry import Polygon
from shapely import wkt

# %%
dataPath = r"C:/Users/conno/OneDrive/MyDocuments/GithubRepositories/Fall2023/traffic_data/"

# %%
# Load via pandas
linkswkt = pd.read_csv(dataPath+"berkeley_links.csv",delimiter=',')
nodeswkt = pd.read_csv(dataPath+"berkeley_nodes.csv",delimiter=',')

# Make into readable wkt format
linkswkt["geometry"] = linkswkt.geometry.apply(wkt.loads)
nodeswkt["geometry"] = nodeswkt.geometry.apply(wkt.loads)
# recreate into geopandas
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22140\3400897033.py in <module>
#       5 # Make into readable wkt format
#       6 linkswkt["geometry"] = linkswkt.geometry.apply(wkt.loads)
# ----> 7 nodeswkt["geometry"] = nodeswkt.geometry.apply(wkt.loads)
#       8 # recreate into geopandas
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'geometry'

# %%
linksgpd = gpd.GeoDataFrame(linkswkt).set_geometry("geometry")

# %%
linksgpd.plot()
# Out:
# <AxesSubplot:>
